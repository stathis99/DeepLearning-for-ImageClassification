# %%
import pandas as pd
import numpy as np
import os
import cv2
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import matplotlib.pyplot as plt

# %%
heatmap_df = pd.read_csv("heat_map.csv", header = 0)

# %%
heatmap_df
# Out:
#      true_labels  pred_labels
# 0              1            1
# 1              1            1
# 2              1            1
# 3              2           63
# 4              2            2
# ..           ...          ...
# 595          199          199
# 596          199          199
# 597          200          200
# 598          200          200
# 599          200          200
#
# [600 rows x 2 columns]

# %%
# Create a confusion matrix
confusion_matrix = pd.crosstab(heatmap_df['true_labels'], heatmap_df['pred_labels'])

# %%
# Plot the heatmap
plt.figure(figsize=(18, 16))
sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %%
confused_rows = heatmap_df[heatmap_df['true_labels'] != heatmap_df['pred_labels']]

confused_rows
# Out:
#      true_labels  pred_labels
# 3              2           63
# 7              3            1
# 24             9           19
# 33            12           56
# 61            21          108
# ..           ...          ...
# 520          174          183
# 531          178           36
# 552          185           65
# 555          186          185
# 573          192          183
#
# [76 rows x 2 columns]
